# %% [markdown]
# # Zanořené cykly a range
#
# Uvažujme, že si vytváříme tabulku, která bude sloužit k rezervaci míst v dopravních prostředcích. Na začátku uvažujeme tabulku pro místa v jednom autobusu. Náš autobus má místa od 1 do 40, proto funkci `range()` zadáme hodnoty 1 a 41 (podobně jako slice je druhé číslo vynechané).

# %%
places = {}
for i in range(1, 41):
    # Vložíme prázdnou hodnotu - na začátku je místo volné
    places[i] = None
# Rezervace místa 5
places[5] = "Jirka Pešík"
# Rezervace místa 6
places[6] = "Jakub Červinka"
print(places)
# Out:
# {1: None, 2: None, 3: None, 4: None, 5: 'Jirka Pešík', 6: 'Jakub Červinka', 7: None, 8: None, 9: None, 10: None, 11: None, 12: None, 13: None, 14: None, 15: None, 16: None, 17: None, 18: None, 19: None, 20: None, 21: None, 22: None, 23: None, 24: None, 25: None, 26: None, 27: None, 28: None, 29: None, 30: None, 31: None, 32: None, 33: None, 34: None, 35: None, 36: None, 37: None, 38: None, 39: None}

# %% [markdown]
# Nyní uvažujme místa v jednom vlaku. Vlak má několik vozů a v každém voze jsou sedačky. Uvažujme třeba místa od 1 do 80 v každém voze a vozy s čísly 1 až 4. Nejprve si výstup vypíšeme na obrazovku.

# %%
places = {}
for i in range(1, 5):
    for j in range(1, 81):
        print(f"Vůz {i}, sedadlo {j}")
# Out:
# Vůz 1, sedadlo 1
# Vůz 1, sedadlo 2
# Vůz 1, sedadlo 3
# Vůz 1, sedadlo 4
# Vůz 1, sedadlo 5
# Vůz 1, sedadlo 6
# Vůz 1, sedadlo 7
# Vůz 1, sedadlo 8
# Vůz 1, sedadlo 9
# Vůz 1, sedadlo 10
# Vůz 1, sedadlo 11
# Vůz 1, sedadlo 12
# Vůz 1, sedadlo 13
# Vůz 1, sedadlo 14
# Vůz 1, sedadlo 15
# Vůz 1, sedadlo 16
# Vůz 1, sedadlo 17
# Vůz 1, sedadlo 18
# Vůz 1, sedadlo 19
# Vůz 1, sedadlo 20
# Vůz 1, sedadlo 21
# Vůz 1, sedadlo 22
# Vůz 1, sedadlo 23
# Vůz 1, sedadlo 24
# Vůz 1, sedadlo 25
# Vůz 1, sedadlo 26
# Vůz 1, sedadlo 27
# Vůz 1, sedadlo 28
# Vůz 1, sedadlo 29
# Vůz 1, sedadlo 30
# Vůz 1, sedadlo 31
# Vůz 1, sedadlo 32
# Vůz 1, sedadlo 33
# Vůz 1, sedadlo 34
# Vůz 1, sedadlo 35
# Vůz 1, sedadlo 36
# Vůz 1, sedadlo 37
# Vůz 1, sedadlo 38
# Vůz 1, sedadlo 39
# Vůz 1, sedadlo 40
# Vůz 1, sedadlo 41
# Vůz 1, sedadlo 42
# Vůz 1, sedadlo 43
# Vůz 1, sedadlo 44
# Vůz 1, sedadlo 45
# Vůz 1, sedadlo 46
# Vůz 1, sedadlo 47
# Vůz 1, sedadlo 48
# Vůz 1, sedadlo 49
# Vůz 1, sedadlo 50
# ...

# %% [markdown]
# Nyní vložíme místa do slovníku. Máme několik možností. První z nich je vícerozměrný klíč ve slovníku, další by byl vícerozměrný slovník. Pro vícerozměrný klíč musíme použít n-tici (tuple).

# %%
places = {}
for i in range(1, 5):
    for j in range(1, 81):
        places[(i, j)] = None
# Rezervace místa 35 ve voze 1
places[(1, 35)] = "Jirka Pešík"
# Rezervace místa 36 ve voze 1
places[(1, 36)] = "Jakub Červinka"

# %% [markdown]
# Třetí rozměr přidáme, pokud uvažujeme několik vlaků. Uvažujme 8 různých vlaků, každý má 4 vozy a každý vůz 80 míst.

# %%
places = {}

for i in range(1, 9):
    for j in range(1, 5):
        for k in range(1, 81):
            print(f"Vlak R{i}, vůz {j}, sedadlo {k}")
            places[(i, j, k)] = None
# Rezervace místa 35 ve voze 1 ve vlaku 3
places[(3, 1, 35)] = "Jirka Pešík"
# Rezervace místa 36 ve voze 1 ve vlaku 3
places[(3, 1, 36)] = "Jakub Červinka"
print(places)
# Out:
# Vlak R1, vůz 1, sedadlo 1
# Vlak R1, vůz 1, sedadlo 2
# Vlak R1, vůz 1, sedadlo 3
# Vlak R1, vůz 1, sedadlo 4
# Vlak R1, vůz 1, sedadlo 5
# Vlak R1, vůz 1, sedadlo 6
# Vlak R1, vůz 1, sedadlo 7
# Vlak R1, vůz 1, sedadlo 8
# Vlak R1, vůz 1, sedadlo 9
# Vlak R1, vůz 1, sedadlo 10
# Vlak R1, vůz 1, sedadlo 11
# Vlak R1, vůz 1, sedadlo 12
# Vlak R1, vůz 1, sedadlo 13
# Vlak R1, vůz 1, sedadlo 14
# Vlak R1, vůz 1, sedadlo 15
# Vlak R1, vůz 1, sedadlo 16
# Vlak R1, vůz 1, sedadlo 17
# Vlak R1, vůz 1, sedadlo 18
# Vlak R1, vůz 1, sedadlo 19
# Vlak R1, vůz 1, sedadlo 20
# Vlak R1, vůz 1, sedadlo 21
# Vlak R1, vůz 1, sedadlo 22
# Vlak R1, vůz 1, sedadlo 23
# Vlak R1, vůz 1, sedadlo 24
# Vlak R1, vůz 1, sedadlo 25
# Vlak R1, vůz 1, sedadlo 26
# Vlak R1, vůz 1, sedadlo 27
# Vlak R1, vůz 1, sedadlo 28
# Vlak R1, vůz 1, sedadlo 29
# Vlak R1, vůz 1, sedadlo 30
# Vlak R1, vůz 1, sedadlo 31
# Vlak R1, vůz 1, sedadlo 32
# Vlak R1, vůz 1, sedadlo 33
# Vlak R1, vůz 1, sedadlo 34
# ...

# %% [markdown]
# Můžeme si zkusit vytvořit i vícerozměrné slovníky. Zde je potřeba v rámci cyklů vytvořit zanořené slovníky, abychom měli kam vkládat hodnoty.

# %%
places = {}

for i in range(1, 9):
    # Vytvoření zanořeného slovníku pro vlak
    places[i] = {}
    for j in range(1, 5):
        # Vytvoření zanořeného slovníku pro vůz
        places[i][j] = {}
        for k in range(1, 81):
            print(f"Vlak R{i}, vůz {j}, sedadlo {k}")
            places[i][j][k] = None
# Rezervace místa 35 ve voze 1 ve vlaku 3
places[3][1][35] = "Jirka Pešík"
# Rezervace místa 36 ve voze 1 ve vlaku 3
places[3][1][36] = "Jakub Červinka"
print(places)
# Out:
# Vlak R1, vůz 1, sedadlo 1
# Vlak R1, vůz 1, sedadlo 2
# Vlak R1, vůz 1, sedadlo 3
# Vlak R1, vůz 1, sedadlo 4
# Vlak R1, vůz 1, sedadlo 5
# Vlak R1, vůz 1, sedadlo 6
# Vlak R1, vůz 1, sedadlo 7
# Vlak R1, vůz 1, sedadlo 8
# Vlak R1, vůz 1, sedadlo 9
# Vlak R1, vůz 1, sedadlo 10
# Vlak R1, vůz 1, sedadlo 11
# Vlak R1, vůz 1, sedadlo 12
# Vlak R1, vůz 1, sedadlo 13
# Vlak R1, vůz 1, sedadlo 14
# Vlak R1, vůz 1, sedadlo 15
# Vlak R1, vůz 1, sedadlo 16
# Vlak R1, vůz 1, sedadlo 17
# Vlak R1, vůz 1, sedadlo 18
# Vlak R1, vůz 1, sedadlo 19
# Vlak R1, vůz 1, sedadlo 20
# Vlak R1, vůz 1, sedadlo 21
# Vlak R1, vůz 1, sedadlo 22
# Vlak R1, vůz 1, sedadlo 23
# Vlak R1, vůz 1, sedadlo 24
# Vlak R1, vůz 1, sedadlo 25
# Vlak R1, vůz 1, sedadlo 26
# Vlak R1, vůz 1, sedadlo 27
# Vlak R1, vůz 1, sedadlo 28
# Vlak R1, vůz 1, sedadlo 29
# Vlak R1, vůz 1, sedadlo 30
# Vlak R1, vůz 1, sedadlo 31
# Vlak R1, vůz 1, sedadlo 32
# Vlak R1, vůz 1, sedadlo 33
# Vlak R1, vůz 1, sedadlo 34
# ...

# %% [markdown]
# Opět je možné využít i modul pandas. Zde použijeme merge (JOIN v SQL) a použijeme typ cross (CROSS JOIN v SQL), což znamená, že se každý řádek z jedné tabulky spojí s každým řádkem z druhé tabulky.

# %%
import pandas

vlaky = pandas.DataFrame(range(1,9), columns=["vlak"])
vozy = pandas.DataFrame(range(1,5), columns=["vuz"])
sedadla = pandas.DataFrame(range(1,81), columns=["sedadlo"])

mista = pandas.merge(vlaky, vozy, how="cross")
mista = pandas.merge(mista, sedadla, how="cross")
mista["osoba"] = None
mista.loc[(mista["vlak"] == 3) & (mista["vuz"] == 1) & (mista["sedadlo"] == 35), "osoba"] = "Jirka Pešík"
mista.loc[(mista["vlak"] == 3) & (mista["vuz"] == 1) & (mista["sedadlo"] == 36), "osoba"] = "Jakub Červinka"

# %% [markdown]
# Pomocí dotazu můžeme zjistit obsazená místa.

# %%
mista[~mista["osoba"].isna()]
# Out:
#      vlak  vuz  sedadlo           osoba
# 674     3    1       35     Jirka Pešík
# 675     3    1       36  Jakub Červinka

# %% [markdown]
# Pomocí dotazů se můžeme podívat třeba na obsazenost vlaků.

# %%
mista.groupby(["vlak"])["osoba"].count()
# Out:
# vlak
# 1    0
# 2    0
# 3    2
# 4    0
# 5    0
# 6    0
# 7    0
# 8    0
# Name: osoba, dtype: int64
